# %% [markdown]
# <a href="https://colab.research.google.com/github/Kasimer-0/CSCI218_Group-FT32/blob/main/AI_Project_%E2%80%94_CNN_v0_1_(1000_Epochs)_(Clean_Version).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, \
    ConfusionMatrixDisplay, \
    classification_report
from timeit import default_timer as timer
from tqdm import tqdm
import pandas as pd
import seaborn as sns

import tensorflow as tf
import tensorflow_datasets as tfds

print("TensorFlow version:", tf.__version__)
print("TFDS version:", tfds.__version__)

import random # Import random for setting seed
# Set global random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
rng = random.Random(42) # Initialise Python's random number generator

# Check for GPU
gpus = tf.config.list_physical_devices('GPU')
print("GPUs available:", gpus)



# ============================================
# Enable Mixed Precision for A100/H100 GPUs (comment out if not in use)
# ============================================

from tensorflow.keras import mixed_precision

# Set the global policy to use mixed_float16
mixed_precision.set_global_policy('mixed_float16')

print('Mixed precision enabled: %s' % mixed_precision.global_policy().name)

# Verify that the policy is set
if tf.config.list_physical_devices('GPU'):
    print("GPU detected. Check policy's compute_dtype and variable_dtype for float16 use.")
else:
    print("No GPU detected, mixed precision will fall back to float32.")

# ============================================
#
# ============================================



import warnings
warnings.filterwarnings('ignore')

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# DATASET_PATH = '/content/drive/MyDrive/Dog dataset'
# zipped_dataset_drive_path = '/content/drive/MyDrive/Dog_dataset.zip'
# local_content_path = '/content/dog_breed_dataset'

# ============================================
# 0. Import ZIP file and extract
# ============================================

# Options selector (comment out the ones that's not being used)
# Zipped file path, change if necessary
# Define the unzip destination for the local /content directory

# ===== 50 classes option ===== #
zipped_dataset_drive_path = '/content/drive/MyDrive/CSCI218 Project/dog_breed_dataset/50_classes.zip'
local_content_path = '/content/dog_breed_dataset/50_classes'

# ===== 120 classes option ===== #
# zipped_dataset_drive_path = '/content/drive/MyDrive/CSCI218 Project/dog_breed_dataset/120_classes.zip'
# local_content_path = '/content/dog_breed_dataset/120_classes'

if os.path.exists(local_content_path):
    print(f"Dataset already extracted to {local_content_path}. Skipping extraction.")
else:
    if not os.path.exists(zipped_dataset_drive_path):
        print(f"Error: Zipped dataset not found at {zipped_dataset_drive_path}")
    else:
        # Determine the name of the zip file in /content
        zip_filename = os.path.basename(zipped_dataset_drive_path)
        copied_zip_path = os.path.join('/content/', zip_filename)

        # Copy zipped file to local /content directory
        print(f"Copying {zipped_dataset_drive_path} to /content/...")
        # !cp "{zipped_dataset_drive_path}" /content/
        print("Copy complete.")

        # Unzip dataset
        print(f"Unzipping dataset to {local_content_path}...")
        # Unzip destination should be the parent directory of local_content_path
        unzip_destination_dir = os.path.dirname(local_content_path)
        os.makedirs(unzip_destination_dir, exist_ok=True) # To ensure parent directory exists

        # !unzip -q "{copied_zip_path}" -d "{unzip_destination_dir}"

        # Optional clean up the copied zip file to save space
        # !rm "{copied_zip_path}"

        print("Unzipping complete.")

# Update DATASET_PATH to point to local /content directory
DATASET_PATH = local_content_path

print(f"Updated DATASET_PATH to: {DATASET_PATH}")

# ============================================
#
# ============================================

print("\n\n\n\n\n")
print("\n" + "="*60)
print("CNN DOG BREED CLASSIFICATION")
print("")

# ============================================
# 1. Data loader
# ============================================

IMG_SIZE = 128      # SET GLOBALLY for Section 1 and Section 4          #####< GLOBAL SETTING FOR IMAGE RESIZING HERE >#####
# IMG_SIZE = 224

def load_dog_dataset(data_path, num_breeds=4, max_images_per_breed=150):
    """Load dog breed images"""

    print(f"Loading data from: {data_path}")

    if 'Images' in os.listdir(data_path):
        data_path = os.path.join(data_path, 'Images')
        print(f"Found Images folder: {data_path}")

    all_breeds = [d for d in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, d))]
    all_breeds.sort()

    print(f"Total breeds available: {len(all_breeds)}")

    selected_breeds = all_breeds[:num_breeds]
    print(f"\nSelected {len(selected_breeds)} breeds for classification:")
    for i, breed in enumerate(selected_breeds):
        print(f"  {i+1}. {breed}")

    images, labels = [], []
    total_loaded = 0

    for breed_idx, breed in enumerate(selected_breeds):
        breed_dir = os.path.join(data_path, breed)
        all_files = os.listdir(breed_dir)

        image_files = []
        for file in all_files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_files.append(file)

        print(f"\n{breed}:")
        print(f"  Found {len(image_files)} image files")

        loaded_count = 0
        for file in image_files[:max_images_per_breed]:
            try:
                img_path = os.path.join(breed_dir, file)

                with Image.open(img_path) as img:
                    img.verify()

                img = Image.open(img_path).convert('RGB')
                # img = img.resize((128, 128))                    # Make sure this resize option is consistent with Section 4
                img = img.resize((IMG_SIZE, IMG_SIZE))            # Based on global settings
                img_array = np.array(img)

                # if img_array.shape == (128, 128, 3):            # Make sure this resize option is consistent with Section 4
                if img_array.shape == (IMG_SIZE, IMG_SIZE, 3):    # Based on global settings
                    images.append(img_array)
                    labels.append(breed_idx)
                    loaded_count += 1
                    total_loaded += 1

                    # Removed data augmentation here; CNN pipeline will handle it
                    # flipped = np.fliplr(img_array)
                    # images.append(flipped)
                    # labels.append(breed_idx)
                    # loaded_count += 1
                    # total_loaded += 1

            except Exception as e:
                continue

        print(f"  Loaded {loaded_count} images (without augmentation, to be handled by TF pipeline)")

    print(f"\n" + "="*60)
    print(f"DATA LOADING COMPLETE")
    print(f"Total images loaded: {total_loaded}")
    print(f"Number of breeds: {len(selected_breeds)}")
    if images:
        print(f"Image shape: {images[0].shape}")
    print("="*60)

    return np.array(images), np.array(labels), selected_breeds

######################################################################################################################################################

# ============================================
# 2. Load the dog dataset for CNN
# ============================================

raw_images, raw_labels, breed_names = load_dog_dataset(
    DATASET_PATH,
    num_breeds=50     # Change this accordingly to the number of breeds being used from the dataset
)

# Just in case, convert breed_names to a list if it's not already (for consistency)
class_names = list(breed_names)
num_classes = len(class_names)

print("Number of classes:", num_classes)
print("Class names:", class_names)

print(f"Total images loaded: {len(raw_images)}")



# ============================================
# 3. Split the loaded data for CNN
# ============================================

# Split data into train, validation, and test sets
# First, split into training and temp (validation + test)
X_train_np, X_temp_np, y_train_np, y_temp_np = train_test_split(
    raw_images, raw_labels,
    test_size=0.4, # 40% for temp (20% val, 20% test)
    random_state=42,
    stratify=raw_labels
)

# Then, split temp into validation and test
X_val_np, X_test_np, y_val_np, y_test_np = train_test_split(
    X_temp_np, y_temp_np,
    test_size=0.5, # 50% of temp for test, 50% for val
    random_state=42,
    stratify=y_temp_np
)

print(f"Training examples: {len(X_train_np)}")
print(f"Validation examples: {len(X_val_np)}")
print(f"Test examples: {len(X_test_np)}")

# Convert NumPy arrays to tf.data.Dataset
ds_train_raw = tf.data.Dataset.from_tensor_slices((X_train_np, y_train_np))
ds_val_raw = tf.data.Dataset.from_tensor_slices((X_val_np, y_val_np))
ds_test_raw = tf.data.Dataset.from_tensor_slices((X_test_np, y_test_np))



# ============================================
# 4. Preprocessing and data pipeline for CNN
# ============================================

# NOTE: Global settings for IMG_SIZE is set in Section 1
# IMG_SIZE = 128    # Option 0
# IMG_SIZE = 224    # Option 1
BATCH_SIZE = 32

def preprocess(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))      # Might be redundant
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

# Simple data augmentation function
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

def augment(image, label):
    # "load_dog_dataset" already loads images resized to 128x128
    # tf.image.resize is redundant, but just for sanity check, can be commented out
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.cast(image, tf.float32) / 255.0
    image = data_augmentation(image)
    return image, label

train_ds = ds_train_raw.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = ds_val_raw.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = ds_test_raw.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)



### DISPLAYING SAMPLE IMAGES to verify data integrity ###
def display_samples(dataset, title, num_samples=5):
    plt.figure(figsize=(15, 3))
    plt.suptitle(title, fontsize=16, fontweight='bold')
    sample_count = 0
    for images, labels in dataset.take(1): # Take one batch
        for i in range(min(num_samples, images.shape[0])):
            ax = plt.subplot(1, num_samples, i + 1)
            # Denormalize and convert to uint8 for display
            img_display = (images[i].numpy() * 255).astype(np.uint8)
            plt.imshow(img_display)
            plt.title(f"Label: {class_names[labels[i].numpy()]}")
            plt.axis("off")
            sample_count += 1
            if sample_count >= num_samples:
                break
    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent suptitle overlap
    plt.show()


print("Displaying sample images from the augmented training dataset:")
display_samples(train_ds, "Augmented Training Samples")

print("\nDisplaying sample images from the preprocessed validation dataset:")
display_samples(val_ds, "Preprocessed Validation Samples")

print("\nDisplaying sample images from the preprocessed test dataset:")
display_samples(test_ds, "Preprocessed Test Samples")



# ============================================
# 5. Create the network architecture for CNN
# ============================================

from tensorflow.keras import layers, models

##### Training from scratch #####
def create_cnn_model(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=num_classes):
    model = models.Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        layers.BatchNormalization(), # Added Batch Normalization
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(), # Added Batch Normalization
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(), # Added Batch Normalization
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(), # Added Batch Normalization
        layers.MaxPooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

##### Using ResNet50 #####
# def create_cnn_model(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=num_classes):
#     # Load a pre-trained ResNet50 model as the base
#     base_model = tf.keras.applications.ResNet50(
#         input_shape=input_shape,
#         include_top=False,  # Don't include the classifier layers at the top
#         weights='imagenet'  # Use weights pre-trained on ImageNet
#     )

#     # Freeze the base model layers so they are not updated during training
#     base_model.trainable = False

#     # Create a new model on top of the base model
#     inputs = tf.keras.Input(shape=input_shape)
#     x = base_model(inputs, training=False) # Keep base model in inference mode for BatchNormalization layers
#     x = layers.GlobalAveragePooling2D()(x)
#     x = layers.Dense(128, activation='relu')(x)
#     x = layers.Dropout(0.5)(x) # Add dropout for regularization
#     outputs = layers.Dense(num_classes, activation='softmax')(x)

#     model = tf.keras.Model(inputs, outputs)
#     return model

model = create_cnn_model()
model.summary()



# ============================================
# 6. Compile and train CNN
# ============================================

model.compile(
    # optimizer='adam',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), # Reduced learning rate
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

EPOCHS = 1000

# Training time calculation + training
start_train = timer()

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS
)

end_train = timer()

print(f"\nTraining Time: {end_train - start_train:.4f} seconds [{((end_train - start_train) / 60):.2f} minutes]")

# ============================================
# 7. Plot training and validation accuracy for CNN
# ============================================

history_dict = history.history

acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
loss = history_dict["loss"]
val_loss = history_dict["val_loss"]

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Train Acc")
plt.plot(epochs_range, val_acc, label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training vs Validation Accuracy")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Train Loss")
plt.plot(epochs_range, val_loss, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs Validation Loss")

plt.tight_layout()
plt.show()

# ============================================
# 8. Generate Confusion Matrix for CNN
# ============================================

from sklearn.metrics import confusion_matrix, classification_report
import itertools

# Evaluate on test set
test_loss, test_acc = model.evaluate(test_ds)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Collect predictions and true labels
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

cm = confusion_matrix(y_true, y_pred)

# # Plot confusion matrix (VERSION 1)
# def plot_confusion_matrix(cm, classes):
#     plt.figure(figsize=(6, 6))
#     plt.imshow(cm, interpolation="nearest")
#     plt.title("Confusion Matrix")
#     plt.colorbar()
#     tick_marks = np.arange(len(classes))
#     plt.xticks(tick_marks, classes, rotation=45)
#     plt.yticks(tick_marks, classes)

#     fmt = "d"
#     thresh = cm.max() / 2.
#     for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
#         plt.text(j, i, format(cm[i, j], fmt),
#                  horizontalalignment="center",
#                  color="white" if cm[i, j] > thresh else "black")

#     plt.ylabel("True label")
#     plt.xlabel("Predicted label")
#     plt.tight_layout()
#     plt.show()

# plot_confusion_matrix(cm, class_names)



# Plot confusion matrix (VERSION 2)
# class_names = val_dataset.dataset.classes                                                                           ##### TO BE DELETED #####
# cm = confusion_matrix(all_labels, all_preds)                                                                        ##### TO BE DELETED #####

plt.figure(figsize=(16, 14))
sns.heatmap(cm, annot=False, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix (50 Dog Breeds)', fontsize=16)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.xticks(rotation=45, ha="right", fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=200)
plt.show()

print("Confusion matrix saved as 'confusion_matrix.png'")



# ============================================
# 9. Detailed Classification Report for CNN
# ============================================

# Generate a complete classification report
# report = classification_report(all_labels, all_preds, target_names=class_names, output_dict=True)                   ##### TO BE DELETED #####
report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)
report_df = pd.DataFrame(report).transpose()

# Print macro average
macro_avg = report['macro avg']
print(f"Macro Avg - Precision: {macro_avg['precision']:.3f}, "
      f"Recall: {macro_avg['recall']:.3f}, F1-Score: {macro_avg['f1-score']:.3f}")

# Identify the best and worst performing categories
report_df_no_summary = report_df.drop(['accuracy', 'macro avg', 'weighted avg'])
top_5_f1 = report_df_no_summary.nlargest(5, 'f1-score')
bottom_5_f1 = report_df_no_summary.nsmallest(5, 'f1-score')

print("\nTop 5 Best Performing Breeds (by F1-Score):")
print(top_5_f1[['f1-score']])

print("\nTop 5 Worst Performing Breeds (by F1-Score):")
print(bottom_5_f1[['f1-score']])



# ============================================
# 10. Visualising classification sample results from the CNN
# ============================================

# sync images with labels
# unbatch the test_ds and take exactly as many images as we have labels for
test_images = []
for imgs, lbls in test_ds.unbatch().take(len(y_true)):
    test_images.append(imgs.numpy())

test_images = np.array(test_images)
y_true_arr = np.array(y_true)
y_pred_arr = np.array(y_pred)

# identify correct and incorrect indices
# reuse the y_true and y_pred variables from evaluation/confusion matrix code above
correct_indices = np.where(y_pred_arr == y_true_arr)[0]
incorrect_indices = np.where(y_pred_arr != y_true_arr)[0]

def plot_images(indices, title):
    plt.figure(figsize=(15, 6))

    for i, idx in enumerate(indices[:5]):   # obtain 5 examples
        plt.subplot(1, 5, i + 1)
        plt.imshow(test_images[idx])

        actual = class_names[y_true_arr[idx]]
        predicted = class_names[y_pred_arr[idx]]

        # additional colour code feature: green for right, red for wrong
        title_color = 'green' if actual == predicted else 'red'

        plt.title(f"Actual: {actual}\nPredicted: {predicted}", color=title_color)    # in case if needed: ..., color=title_color)
        plt.axis('off')

    plt.suptitle(title, fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()

plot_images(correct_indices, "5 Correctly Classified Images")
plot_images(incorrect_indices, "5 Incorrectly Classified Images")



# ============================================
# 10. Automatically Disconnect Runtime
# ============================================

from google.colab import drive, runtime
from IPython.display import display, Javascript

def disconnect_runtime():
  js = Javascript('''
    setTimeout(() => {
      console.log('Disconnecting runtime...');
      document.querySelector('#connect-button /deep/ #text').dispatchEvent(new MouseEvent('mousedown', {bubbles: true}));
      setTimeout(() => {
        document.querySelector('#disconnect /deep/ #text').dispatchEvent(new MouseEvent('mousedown', {bubbles: true}));
      }, 1000);
    }, 1000);
  ''')
  display(js)

disconnect_runtime()
# Out:
# TensorFlow version: 2.19.0
# TFDS version: 4.9.9
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Mixed precision enabled: mixed_float16
# GPU detected. Check policy's compute_dtype and variable_dtype for float16 use.
# Mounted at /content/drive
# Copying /content/drive/MyDrive/CSCI218 Project/dog_breed_dataset/50_classes.zip to /content/...
# Copy complete.
# Unzipping dataset to /content/dog_breed_dataset/50_classes...
# Unzipping complete.
# Updated DATASET_PATH to: /content/dog_breed_dataset/50_classes
#
#
#
#
#
#
#
# ============================================================
# CNN DOG BREED CLASSIFICATION
#
# Loading data from: /content/dog_breed_dataset/50_classes
# Found Images folder: /content/dog_breed_dataset/50_classes/Images
# Total breeds available: 50
#
# Selected 50 breeds for classification:
#   1. n02085620-Chihuahua
#   2. n02085782-Japanese_spaniel
#   3. n02085936-Maltese_dog
#   4. n02086079-Pekinese
#   5. n02086240-Shih-Tzu
#   6. n02086646-Blenheim_spaniel
#   7. n02086910-papillon
#   8. n02087046-toy_terrier
#   9. n02087394-Rhodesian_ridgeback
#   10. n02088094-Afghan_hound
#   11. n02088238-basset
#   12. n02088364-beagle
#   13. n02088466-bloodhound
#   14. n02088632-bluetick
#   15. n02089078-black-and-tan_coonhound
#   16. n02089867-Walker_hound
#   17. n02089973-English_foxhound
#   18. n02090379-redbone
#   19. n02090622-borzoi
#   20. n02090721-Irish_wolfhound
#   21. n02091032-Italian_greyhound
#   22. n02091134-whippet
#   23. n02091244-Ibizan_hound
#   24. n02091467-Norwegian_elkhound
#   25. n02091635-otterhound
#   26. n02091831-Saluki
#   27. n02092002-Scottish_deerhound
#   28. n02092339-Weimaraner
#   29. n02093256-Staffordshire_bullterrier
#   30. n02093428-American_Staffordshire_terrier
#   31. n02093647-Bedlington_terrier
#   32. n02093754-Border_terrier
#   33. n02093859-Kerry_blue_terrier
#   34. n02093991-Irish_terrier
#   35. n02094114-Norfolk_terrier
#   36. n02094258-Norwich_terrier
#   37. n02094433-Yorkshire_terrier
#   38. n02095314-wire-haired_fox_terrier
#   39. n02095570-Lakeland_terrier
#   40. n02095889-Sealyham_terrier
#   41. n02096177-cairn
#   42. n02099601-golden_retriever
#   43. n02099712-Labrador_retriever
#   44. n02106550-Rottweiler
#   45. n02106662-German_shepherd
#   46. n02108089-boxer
#   47. n02108915-French_bulldog
#   48. n02113624-toy_poodle
#   49. n02113712-miniature_poodle
#   50. n02113799-standard_poodle
#
# n02085620-Chihuahua:
#   Found 152 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02085782-Japanese_spaniel:
#   Found 185 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02085936-Maltese_dog:
#   Found 252 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02086079-Pekinese:
#   Found 149 image files
#   Loaded 149 images (without augmentation, to be handled by TF pipeline)
#
# n02086240-Shih-Tzu:
#   Found 214 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02086646-Blenheim_spaniel:
#   Found 188 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02086910-papillon:
#   Found 196 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02087046-toy_terrier:
#   Found 172 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02087394-Rhodesian_ridgeback:
#   Found 172 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02088094-Afghan_hound:
#   Found 239 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02088238-basset:
#   Found 175 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02088364-beagle:
#   Found 195 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02088466-bloodhound:
#   Found 187 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02088632-bluetick:
#   Found 171 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02089078-black-and-tan_coonhound:
#   Found 159 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02089867-Walker_hound:
#   Found 153 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02089973-English_foxhound:
#   Found 157 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02090379-redbone:
#   Found 148 image files
#   Loaded 148 images (without augmentation, to be handled by TF pipeline)
#
# n02090622-borzoi:
#   Found 151 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02090721-Irish_wolfhound:
#   Found 218 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02091032-Italian_greyhound:
#   Found 182 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02091134-whippet:
#   Found 187 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02091244-Ibizan_hound:
#   Found 188 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02091467-Norwegian_elkhound:
#   Found 196 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02091635-otterhound:
#   Found 151 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02091831-Saluki:
#   Found 200 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02092002-Scottish_deerhound:
#   Found 232 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02092339-Weimaraner:
#   Found 160 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02093256-Staffordshire_bullterrier:
#   Found 155 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02093428-American_Staffordshire_terrier:
#   Found 164 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02093647-Bedlington_terrier:
#   Found 182 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02093754-Border_terrier:
#   Found 172 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02093859-Kerry_blue_terrier:
#   Found 179 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02093991-Irish_terrier:
#   Found 169 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02094114-Norfolk_terrier:
#   Found 172 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02094258-Norwich_terrier:
#   Found 185 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02094433-Yorkshire_terrier:
#   Found 164 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02095314-wire-haired_fox_terrier:
#   Found 157 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02095570-Lakeland_terrier:
#   Found 197 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02095889-Sealyham_terrier:
#   Found 202 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02096177-cairn:
#   Found 197 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02099601-golden_retriever:
#   Found 150 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02099712-Labrador_retriever:
#   Found 171 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02106550-Rottweiler:
#   Found 152 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02106662-German_shepherd:
#   Found 152 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02108089-boxer:
#   Found 151 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02108915-French_bulldog:
#   Found 159 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02113624-toy_poodle:
#   Found 151 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02113712-miniature_poodle:
#   Found 155 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# n02113799-standard_poodle:
#   Found 159 image files
#   Loaded 150 images (without augmentation, to be handled by TF pipeline)
#
# ============================================================
# DATA LOADING COMPLETE
# Total images loaded: 7497
# Number of breeds: 50
# Image shape: (128, 128, 3)
# ============================================================
# Number of classes: 50
# Class names: ['n02085620-Chihuahua', 'n02085782-Japanese_spaniel', 'n02085936-Maltese_dog', 'n02086079-Pekinese', 'n02086240-Shih-Tzu', 'n02086646-Blenheim_spaniel', 'n02086910-papillon', 'n02087046-toy_terrier', 'n02087394-Rhodesian_ridgeback', 'n02088094-Afghan_hound', 'n02088238-basset', 'n02088364-beagle', 'n02088466-bloodhound', 'n02088632-bluetick', 'n02089078-black-and-tan_coonhound', 'n02089867-Walker_hound', 'n02089973-English_foxhound', 'n02090379-redbone', 'n02090622-borzoi', 'n02090721-Irish_wolfhound', 'n02091032-Italian_greyhound', 'n02091134-whippet', 'n02091244-Ibizan_hound', 'n02091467-Norwegian_elkhound', 'n02091635-otterhound', 'n02091831-Saluki', 'n02092002-Scottish_deerhound', 'n02092339-Weimaraner', 'n02093256-Staffordshire_bullterrier', 'n02093428-American_Staffordshire_terrier', 'n02093647-Bedlington_terrier', 'n02093754-Border_terrier', 'n02093859-Kerry_blue_terrier', 'n02093991-Irish_terrier', 'n02094114-Norfolk_terrier', 'n02094258-Norwich_terrier', 'n02094433-Yorkshire_terrier', 'n02095314-wire-haired_fox_terrier', 'n02095570-Lakeland_terrier', 'n02095889-Sealyham_terrier', 'n02096177-cairn', 'n02099601-golden_retriever', 'n02099712-Labrador_retriever', 'n02106550-Rottweiler', 'n02106662-German_shepherd', 'n02108089-boxer', 'n02108915-French_bulldog', 'n02113624-toy_poodle', 'n02113712-miniature_poodle', 'n02113799-standard_poodle']
# Total images loaded: 7497
# Training examples: 4498
# Validation examples: 1499
# Test examples: 1500
# Displaying sample images from the augmented training dataset:
# Displaying sample images from the preprocessed validation dataset:
# Displaying sample images from the preprocessed test dataset:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,494,066 (9.51 MB)
#  Trainable params: 2,493,106 (9.51 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 28s 104ms/step - accuracy: 0.0172 - loss: 4.8248 - val_accuracy: 0.0187 - val_loss: 5.8528
# Epoch 2/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0211 - loss: 3.9134 - val_accuracy: 0.0193 - val_loss: 4.6132
# Epoch 3/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0282 - loss: 3.9058 - val_accuracy: 0.0247 - val_loss: 3.9381
# Epoch 4/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0235 - loss: 3.8983 - val_accuracy: 0.0287 - val_loss: 3.8832
# Epoch 5/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0215 - loss: 3.9025 - val_accuracy: 0.0340 - val_loss: 3.8734
# Epoch 6/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0257 - loss: 3.8889 - val_accuracy: 0.0280 - val_loss: 3.8784
# Epoch 7/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0266 - loss: 3.8876 - val_accuracy: 0.0307 - val_loss: 3.8837
# Epoch 8/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0332 - loss: 3.8859 - val_accuracy: 0.0327 - val_loss: 3.8875
# Epoch 9/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0349 - loss: 3.8823 - val_accuracy: 0.0354 - val_loss: 3.8664
# Epoch 10/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0383 - loss: 3.8706 - val_accuracy: 0.0387 - val_loss: 3.8884
# Epoch 11/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0309 - loss: 3.8731 - val_accuracy: 0.0347 - val_loss: 3.8617
# Epoch 12/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0417 - loss: 3.8574 - val_accuracy: 0.0474 - val_loss: 3.8390
# Epoch 13/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0364 - loss: 3.8529 - val_accuracy: 0.0440 - val_loss: 3.8488
# Epoch 14/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0291 - loss: 3.8808 - val_accuracy: 0.0374 - val_loss: 3.8626
# Epoch 15/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0354 - loss: 3.8368 - val_accuracy: 0.0367 - val_loss: 3.8488
# Epoch 16/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0416 - loss: 3.8163 - val_accuracy: 0.0420 - val_loss: 3.8491
# Epoch 17/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0328 - loss: 3.8344 - val_accuracy: 0.0460 - val_loss: 3.8433
# Epoch 18/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0419 - loss: 3.8207 - val_accuracy: 0.0427 - val_loss: 3.8339
# Epoch 19/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0501 - loss: 3.8002 - val_accuracy: 0.0460 - val_loss: 3.8366
# Epoch 20/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0392 - loss: 3.8221 - val_accuracy: 0.0460 - val_loss: 3.8260
# Epoch 21/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0464 - loss: 3.7926 - val_accuracy: 0.0520 - val_loss: 3.8098
# Epoch 22/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0447 - loss: 3.7809 - val_accuracy: 0.0527 - val_loss: 3.8076
# Epoch 23/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0575 - loss: 3.7889 - val_accuracy: 0.0520 - val_loss: 3.8203
# Epoch 24/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0537 - loss: 3.7715 - val_accuracy: 0.0587 - val_loss: 3.7785
# Epoch 25/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0550 - loss: 3.7329 - val_accuracy: 0.0574 - val_loss: 3.8297
# Epoch 26/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0606 - loss: 3.7454 - val_accuracy: 0.0574 - val_loss: 3.7824
# Epoch 27/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0513 - loss: 3.7467 - val_accuracy: 0.0554 - val_loss: 3.7570
# Epoch 28/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0521 - loss: 3.7543 - val_accuracy: 0.0540 - val_loss: 3.7897
# Epoch 29/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0601 - loss: 3.6934 - val_accuracy: 0.0634 - val_loss: 3.7736
# Epoch 30/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0659 - loss: 3.7126 - val_accuracy: 0.0600 - val_loss: 3.7645
# Epoch 31/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0705 - loss: 3.7026 - val_accuracy: 0.0614 - val_loss: 3.7548
# Epoch 32/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0633 - loss: 3.7101 - val_accuracy: 0.0614 - val_loss: 3.7432
# Epoch 33/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0637 - loss: 3.6750 - val_accuracy: 0.0627 - val_loss: 3.8064
# Epoch 34/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0707 - loss: 3.6754 - val_accuracy: 0.0634 - val_loss: 3.7438
# Epoch 35/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0679 - loss: 3.6839 - val_accuracy: 0.0660 - val_loss: 3.7601
# Epoch 36/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0825 - loss: 3.6375 - val_accuracy: 0.0647 - val_loss: 3.7385
# Epoch 37/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0780 - loss: 3.6469 - val_accuracy: 0.0607 - val_loss: 3.7303
# Epoch 38/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0758 - loss: 3.6032 - val_accuracy: 0.0667 - val_loss: 3.7293
# Epoch 39/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0803 - loss: 3.6187 - val_accuracy: 0.0740 - val_loss: 3.7317
# Epoch 40/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0811 - loss: 3.5954 - val_accuracy: 0.0740 - val_loss: 3.7195
# Epoch 41/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0747 - loss: 3.5996 - val_accuracy: 0.0707 - val_loss: 3.7209
# Epoch 42/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0831 - loss: 3.5721 - val_accuracy: 0.0754 - val_loss: 3.7192
# Epoch 43/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0897 - loss: 3.5550 - val_accuracy: 0.0874 - val_loss: 3.7265
# Epoch 44/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0915 - loss: 3.5219 - val_accuracy: 0.0734 - val_loss: 3.7844
# Epoch 45/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0960 - loss: 3.5333 - val_accuracy: 0.0847 - val_loss: 3.7189
# Epoch 46/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0962 - loss: 3.5308 - val_accuracy: 0.0794 - val_loss: 3.7162
# Epoch 47/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1007 - loss: 3.4878 - val_accuracy: 0.0827 - val_loss: 3.7113
# Epoch 48/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1042 - loss: 3.4814 - val_accuracy: 0.0941 - val_loss: 3.6589
# Epoch 49/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1029 - loss: 3.4645 - val_accuracy: 0.0867 - val_loss: 3.6705
# Epoch 50/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1155 - loss: 3.4438 - val_accuracy: 0.0874 - val_loss: 3.6572
# Epoch 51/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1126 - loss: 3.4001 - val_accuracy: 0.0754 - val_loss: 3.7537
# Epoch 52/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1176 - loss: 3.4248 - val_accuracy: 0.0834 - val_loss: 3.6541
# Epoch 53/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1140 - loss: 3.4008 - val_accuracy: 0.0861 - val_loss: 3.6655
# Epoch 54/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1120 - loss: 3.3860 - val_accuracy: 0.0907 - val_loss: 3.6573
# Epoch 55/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1184 - loss: 3.3714 - val_accuracy: 0.0934 - val_loss: 3.6653
# Epoch 56/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1248 - loss: 3.3668 - val_accuracy: 0.0961 - val_loss: 3.6217
# Epoch 57/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1406 - loss: 3.3152 - val_accuracy: 0.1014 - val_loss: 3.6771
# Epoch 58/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1310 - loss: 3.3325 - val_accuracy: 0.0941 - val_loss: 3.6150
# Epoch 59/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1333 - loss: 3.2982 - val_accuracy: 0.0994 - val_loss: 3.6245
# Epoch 60/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1331 - loss: 3.3050 - val_accuracy: 0.0987 - val_loss: 3.6363
# Epoch 61/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1438 - loss: 3.2629 - val_accuracy: 0.0947 - val_loss: 3.6072
# Epoch 62/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1582 - loss: 3.2516 - val_accuracy: 0.1001 - val_loss: 3.6577
# Epoch 63/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1487 - loss: 3.2442 - val_accuracy: 0.1214 - val_loss: 3.5455
# Epoch 64/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1616 - loss: 3.2066 - val_accuracy: 0.1114 - val_loss: 3.5945
# Epoch 65/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1528 - loss: 3.2003 - val_accuracy: 0.1087 - val_loss: 3.6100
# Epoch 66/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1518 - loss: 3.1968 - val_accuracy: 0.1308 - val_loss: 3.5573
# Epoch 67/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1568 - loss: 3.1703 - val_accuracy: 0.1174 - val_loss: 3.5836
# Epoch 68/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1632 - loss: 3.1841 - val_accuracy: 0.1127 - val_loss: 3.6075
# Epoch 69/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1708 - loss: 3.1384 - val_accuracy: 0.1174 - val_loss: 3.5597
# Epoch 70/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1688 - loss: 3.0896 - val_accuracy: 0.1047 - val_loss: 3.6053
# Epoch 71/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1767 - loss: 3.0613 - val_accuracy: 0.1194 - val_loss: 3.5436
# Epoch 72/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1748 - loss: 3.0543 - val_accuracy: 0.1167 - val_loss: 3.5725
# Epoch 73/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1782 - loss: 3.0474 - val_accuracy: 0.1121 - val_loss: 3.6057
# Epoch 74/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1799 - loss: 3.0450 - val_accuracy: 0.1167 - val_loss: 3.6778
# Epoch 75/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1786 - loss: 3.0556 - val_accuracy: 0.1141 - val_loss: 3.5869
# Epoch 76/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1986 - loss: 3.0101 - val_accuracy: 0.1134 - val_loss: 3.5608
# Epoch 77/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1953 - loss: 2.9913 - val_accuracy: 0.1201 - val_loss: 3.5903
# Epoch 78/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2003 - loss: 2.9853 - val_accuracy: 0.1301 - val_loss: 3.5557
# Epoch 79/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1988 - loss: 2.9733 - val_accuracy: 0.1281 - val_loss: 3.5272
# Epoch 80/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1939 - loss: 2.9826 - val_accuracy: 0.1261 - val_loss: 3.5434
# Epoch 81/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2098 - loss: 2.9058 - val_accuracy: 0.1341 - val_loss: 3.5655
# Epoch 82/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2235 - loss: 2.8822 - val_accuracy: 0.1414 - val_loss: 3.5083
# Epoch 83/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2104 - loss: 2.8942 - val_accuracy: 0.1294 - val_loss: 3.5615
# Epoch 84/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2222 - loss: 2.8745 - val_accuracy: 0.1288 - val_loss: 3.5312
# Epoch 85/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2235 - loss: 2.8894 - val_accuracy: 0.1268 - val_loss: 3.5892
# Epoch 86/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2291 - loss: 2.8297 - val_accuracy: 0.1254 - val_loss: 3.5754
# Epoch 87/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2201 - loss: 2.8353 - val_accuracy: 0.1254 - val_loss: 3.5765
# Epoch 88/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2203 - loss: 2.8453 - val_accuracy: 0.1167 - val_loss: 3.5647
# Epoch 89/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2272 - loss: 2.7895 - val_accuracy: 0.1341 - val_loss: 3.5445
# Epoch 90/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2463 - loss: 2.7383 - val_accuracy: 0.1441 - val_loss: 3.5118
# Epoch 91/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2534 - loss: 2.7390 - val_accuracy: 0.1201 - val_loss: 3.6133
# Epoch 92/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2392 - loss: 2.7709 - val_accuracy: 0.1354 - val_loss: 3.5428
# Epoch 93/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2463 - loss: 2.7598 - val_accuracy: 0.1374 - val_loss: 3.5337
# Epoch 94/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2441 - loss: 2.7053 - val_accuracy: 0.1381 - val_loss: 3.5850
# Epoch 95/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2485 - loss: 2.7197 - val_accuracy: 0.1308 - val_loss: 3.5406
# Epoch 96/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2642 - loss: 2.6789 - val_accuracy: 0.1388 - val_loss: 3.5058
# Epoch 97/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2668 - loss: 2.6514 - val_accuracy: 0.1421 - val_loss: 3.4899
# Epoch 98/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2867 - loss: 2.6073 - val_accuracy: 0.1374 - val_loss: 3.6750
# Epoch 99/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2732 - loss: 2.6338 - val_accuracy: 0.1521 - val_loss: 3.5564
# Epoch 100/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2768 - loss: 2.5967 - val_accuracy: 0.1494 - val_loss: 3.4817
# Epoch 101/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2722 - loss: 2.5943 - val_accuracy: 0.1428 - val_loss: 3.6148
# Epoch 102/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2947 - loss: 2.5595 - val_accuracy: 0.1381 - val_loss: 3.5949
# Epoch 103/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2813 - loss: 2.5785 - val_accuracy: 0.1621 - val_loss: 3.5229
# Epoch 104/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2840 - loss: 2.5461 - val_accuracy: 0.1288 - val_loss: 3.6752
# Epoch 105/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3092 - loss: 2.4717 - val_accuracy: 0.1541 - val_loss: 3.5715
# Epoch 106/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3038 - loss: 2.4909 - val_accuracy: 0.1454 - val_loss: 3.4934
# Epoch 107/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3141 - loss: 2.4624 - val_accuracy: 0.1534 - val_loss: 3.5224
# Epoch 108/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3017 - loss: 2.4670 - val_accuracy: 0.1488 - val_loss: 3.6031
# Epoch 109/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3219 - loss: 2.4092 - val_accuracy: 0.1508 - val_loss: 3.5900
# Epoch 110/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3085 - loss: 2.4506 - val_accuracy: 0.1434 - val_loss: 3.7104
# Epoch 111/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3210 - loss: 2.3973 - val_accuracy: 0.1421 - val_loss: 3.6174
# Epoch 112/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3060 - loss: 2.4313 - val_accuracy: 0.1534 - val_loss: 3.5929
# Epoch 113/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3203 - loss: 2.3957 - val_accuracy: 0.1681 - val_loss: 3.5757
# Epoch 114/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3147 - loss: 2.3684 - val_accuracy: 0.1514 - val_loss: 3.6386
# Epoch 115/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3304 - loss: 2.3730 - val_accuracy: 0.1701 - val_loss: 3.5557
# Epoch 116/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3374 - loss: 2.3075 - val_accuracy: 0.1614 - val_loss: 3.6901
# Epoch 117/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3429 - loss: 2.3032 - val_accuracy: 0.1514 - val_loss: 3.7256
# Epoch 118/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3454 - loss: 2.2882 - val_accuracy: 0.1674 - val_loss: 3.5616
# Epoch 119/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3533 - loss: 2.2541 - val_accuracy: 0.1514 - val_loss: 3.6202
# Epoch 120/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3617 - loss: 2.2203 - val_accuracy: 0.1641 - val_loss: 3.5469
# Epoch 121/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3477 - loss: 2.2528 - val_accuracy: 0.1641 - val_loss: 3.6254
# Epoch 122/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3673 - loss: 2.2474 - val_accuracy: 0.1601 - val_loss: 3.5882
# Epoch 123/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3706 - loss: 2.1953 - val_accuracy: 0.1601 - val_loss: 3.6522
# Epoch 124/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3670 - loss: 2.2079 - val_accuracy: 0.1808 - val_loss: 3.5146
# Epoch 125/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3576 - loss: 2.2060 - val_accuracy: 0.1748 - val_loss: 3.5829
# Epoch 126/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3797 - loss: 2.1701 - val_accuracy: 0.1614 - val_loss: 3.6449
# Epoch 127/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3759 - loss: 2.1779 - val_accuracy: 0.1521 - val_loss: 3.7308
# Epoch 128/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3876 - loss: 2.1368 - val_accuracy: 0.1781 - val_loss: 3.5314
# Epoch 129/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3811 - loss: 2.1418 - val_accuracy: 0.1708 - val_loss: 3.6310
# Epoch 130/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3847 - loss: 2.1048 - val_accuracy: 0.1761 - val_loss: 3.5085
# Epoch 131/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3854 - loss: 2.0723 - val_accuracy: 0.1661 - val_loss: 3.6606
# Epoch 132/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4089 - loss: 2.0354 - val_accuracy: 0.1574 - val_loss: 3.7195
# Epoch 133/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3893 - loss: 2.0770 - val_accuracy: 0.1514 - val_loss: 3.6180
# Epoch 134/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3908 - loss: 2.0970 - val_accuracy: 0.1654 - val_loss: 3.6205
# Epoch 135/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4062 - loss: 2.0451 - val_accuracy: 0.1748 - val_loss: 3.5758
# Epoch 136/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4121 - loss: 2.0552 - val_accuracy: 0.1721 - val_loss: 3.7139
# Epoch 137/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4311 - loss: 1.9715 - val_accuracy: 0.1741 - val_loss: 3.7584
# Epoch 138/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4176 - loss: 2.0133 - val_accuracy: 0.1608 - val_loss: 3.7706
# Epoch 139/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4054 - loss: 2.0104 - val_accuracy: 0.1775 - val_loss: 3.7510
# Epoch 140/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4461 - loss: 1.9265 - val_accuracy: 0.1588 - val_loss: 3.7283
# Epoch 141/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4370 - loss: 1.9647 - val_accuracy: 0.1861 - val_loss: 3.6976
# Epoch 142/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4407 - loss: 1.9268 - val_accuracy: 0.1888 - val_loss: 3.7059
# Epoch 143/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4361 - loss: 1.9098 - val_accuracy: 0.1734 - val_loss: 3.7520
# Epoch 144/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4376 - loss: 1.9470 - val_accuracy: 0.1815 - val_loss: 3.6403
# Epoch 145/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4471 - loss: 1.8581 - val_accuracy: 0.1788 - val_loss: 3.7712
# Epoch 146/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4368 - loss: 1.8857 - val_accuracy: 0.1741 - val_loss: 3.7706
# Epoch 147/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4467 - loss: 1.8799 - val_accuracy: 0.1775 - val_loss: 3.7944
# Epoch 148/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4668 - loss: 1.7882 - val_accuracy: 0.2028 - val_loss: 3.7140
# Epoch 149/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4625 - loss: 1.8397 - val_accuracy: 0.1801 - val_loss: 3.6882
# Epoch 150/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4680 - loss: 1.7984 - val_accuracy: 0.1935 - val_loss: 3.6047
# Epoch 151/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4696 - loss: 1.7796 - val_accuracy: 0.1795 - val_loss: 3.7362
# Epoch 152/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4780 - loss: 1.8078 - val_accuracy: 0.1908 - val_loss: 3.6412
# Epoch 153/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4676 - loss: 1.7643 - val_accuracy: 0.1835 - val_loss: 3.6929
# Epoch 154/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4741 - loss: 1.7891 - val_accuracy: 0.1741 - val_loss: 3.8089
# Epoch 155/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4533 - loss: 1.7736 - val_accuracy: 0.1821 - val_loss: 3.9163
# Epoch 156/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4716 - loss: 1.7539 - val_accuracy: 0.1955 - val_loss: 3.7504
# Epoch 157/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4953 - loss: 1.7370 - val_accuracy: 0.1688 - val_loss: 3.9160
# Epoch 158/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4920 - loss: 1.7200 - val_accuracy: 0.1901 - val_loss: 3.8136
# Epoch 159/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4787 - loss: 1.7426 - val_accuracy: 0.2008 - val_loss: 3.7653
# Epoch 160/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4703 - loss: 1.7527 - val_accuracy: 0.1875 - val_loss: 3.7924
# Epoch 161/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5064 - loss: 1.7201 - val_accuracy: 0.1795 - val_loss: 3.8169
# Epoch 162/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5097 - loss: 1.6481 - val_accuracy: 0.1981 - val_loss: 3.9051
# Epoch 163/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4756 - loss: 1.7332 - val_accuracy: 0.1741 - val_loss: 3.8728
# Epoch 164/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5014 - loss: 1.6702 - val_accuracy: 0.1941 - val_loss: 3.9054
# Epoch 165/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5118 - loss: 1.6310 - val_accuracy: 0.1848 - val_loss: 3.9048
# Epoch 166/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5267 - loss: 1.6123 - val_accuracy: 0.1821 - val_loss: 3.8922
# Epoch 167/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5142 - loss: 1.6229 - val_accuracy: 0.1895 - val_loss: 3.8300
# Epoch 168/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4894 - loss: 1.6639 - val_accuracy: 0.1775 - val_loss: 4.1187
# Epoch 169/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5084 - loss: 1.6255 - val_accuracy: 0.1888 - val_loss: 3.9435
# Epoch 170/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5136 - loss: 1.6171 - val_accuracy: 0.1988 - val_loss: 3.8306
# Epoch 171/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5529 - loss: 1.5340 - val_accuracy: 0.1808 - val_loss: 3.9795
# Epoch 172/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5304 - loss: 1.5581 - val_accuracy: 0.1975 - val_loss: 3.9980
# Epoch 173/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5290 - loss: 1.6016 - val_accuracy: 0.1755 - val_loss: 4.1326
# Epoch 174/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5343 - loss: 1.5516 - val_accuracy: 0.1975 - val_loss: 4.0181
# Epoch 175/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5413 - loss: 1.5173 - val_accuracy: 0.2075 - val_loss: 3.8921
# Epoch 176/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5426 - loss: 1.4787 - val_accuracy: 0.1855 - val_loss: 3.9861
# Epoch 177/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5509 - loss: 1.4841 - val_accuracy: 0.1901 - val_loss: 4.0695
# Epoch 178/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5406 - loss: 1.4977 - val_accuracy: 0.1881 - val_loss: 3.9003
# Epoch 179/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5375 - loss: 1.4897 - val_accuracy: 0.1841 - val_loss: 3.8471
# Epoch 180/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5658 - loss: 1.4379 - val_accuracy: 0.1921 - val_loss: 4.1617
# Epoch 181/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5437 - loss: 1.4846 - val_accuracy: 0.1868 - val_loss: 4.0019
# Epoch 182/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5462 - loss: 1.4851 - val_accuracy: 0.1841 - val_loss: 4.1091
# Epoch 183/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5773 - loss: 1.3946 - val_accuracy: 0.1881 - val_loss: 4.0801
# Epoch 184/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5646 - loss: 1.4098 - val_accuracy: 0.2015 - val_loss: 4.0519
# Epoch 185/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5869 - loss: 1.3780 - val_accuracy: 0.1968 - val_loss: 3.9287
# Epoch 186/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5911 - loss: 1.3569 - val_accuracy: 0.1888 - val_loss: 4.1589
# Epoch 187/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5798 - loss: 1.4047 - val_accuracy: 0.1895 - val_loss: 4.2425
# Epoch 188/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5804 - loss: 1.4008 - val_accuracy: 0.1935 - val_loss: 4.0584
# Epoch 189/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5891 - loss: 1.3364 - val_accuracy: 0.1975 - val_loss: 4.0380
# Epoch 190/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5873 - loss: 1.3517 - val_accuracy: 0.1928 - val_loss: 4.1406
# Epoch 191/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5923 - loss: 1.3438 - val_accuracy: 0.2095 - val_loss: 4.1615
# Epoch 192/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5823 - loss: 1.4024 - val_accuracy: 0.2028 - val_loss: 4.0729
# Epoch 193/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5807 - loss: 1.3597 - val_accuracy: 0.2075 - val_loss: 4.0676
# Epoch 194/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5832 - loss: 1.3797 - val_accuracy: 0.1975 - val_loss: 4.1559
# Epoch 195/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6042 - loss: 1.2880 - val_accuracy: 0.2001 - val_loss: 3.9014
# Epoch 196/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6001 - loss: 1.3032 - val_accuracy: 0.2015 - val_loss: 3.9339
# Epoch 197/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5983 - loss: 1.3177 - val_accuracy: 0.1948 - val_loss: 4.2848
# Epoch 198/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5841 - loss: 1.3506 - val_accuracy: 0.2095 - val_loss: 4.1228
# Epoch 199/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5955 - loss: 1.3198 - val_accuracy: 0.2075 - val_loss: 4.2055
# Epoch 200/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6027 - loss: 1.2734 - val_accuracy: 0.1821 - val_loss: 4.1815
# Epoch 201/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6182 - loss: 1.2583 - val_accuracy: 0.2015 - val_loss: 4.0701
# Epoch 202/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6030 - loss: 1.2705 - val_accuracy: 0.2008 - val_loss: 4.2733
# Epoch 203/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6115 - loss: 1.2483 - val_accuracy: 0.2055 - val_loss: 4.2275
# Epoch 204/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6141 - loss: 1.2649 - val_accuracy: 0.2075 - val_loss: 4.1438
# Epoch 205/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6111 - loss: 1.2605 - val_accuracy: 0.1928 - val_loss: 4.1905
# Epoch 206/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6231 - loss: 1.2369 - val_accuracy: 0.1981 - val_loss: 4.1563
# Epoch 207/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6303 - loss: 1.1869 - val_accuracy: 0.1961 - val_loss: 4.3259
# Epoch 208/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6048 - loss: 1.2795 - val_accuracy: 0.1928 - val_loss: 4.1478
# Epoch 209/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6256 - loss: 1.2053 - val_accuracy: 0.2041 - val_loss: 4.1315
# Epoch 210/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6427 - loss: 1.1263 - val_accuracy: 0.2141 - val_loss: 4.1474
# Epoch 211/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6275 - loss: 1.1850 - val_accuracy: 0.2008 - val_loss: 4.3470
# Epoch 212/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6384 - loss: 1.1974 - val_accuracy: 0.2115 - val_loss: 4.0744
# Epoch 213/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6320 - loss: 1.2082 - val_accuracy: 0.1995 - val_loss: 4.2670
# Epoch 214/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6413 - loss: 1.1764 - val_accuracy: 0.1968 - val_loss: 4.3153
# Epoch 215/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6538 - loss: 1.1349 - val_accuracy: 0.2055 - val_loss: 4.2553
# Epoch 216/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6465 - loss: 1.1294 - val_accuracy: 0.2121 - val_loss: 4.2374
# Epoch 217/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6548 - loss: 1.0974 - val_accuracy: 0.2061 - val_loss: 4.2223
# Epoch 218/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6422 - loss: 1.1536 - val_accuracy: 0.2015 - val_loss: 4.2001
# Epoch 219/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6526 - loss: 1.1075 - val_accuracy: 0.2035 - val_loss: 4.3302
# Epoch 220/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6587 - loss: 1.1032 - val_accuracy: 0.2015 - val_loss: 4.3116
# Epoch 221/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6476 - loss: 1.1084 - val_accuracy: 0.2028 - val_loss: 4.1343
# Epoch 222/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6554 - loss: 1.0873 - val_accuracy: 0.2101 - val_loss: 4.2491
# Epoch 223/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6474 - loss: 1.1137 - val_accuracy: 0.2188 - val_loss: 4.3480
# Epoch 224/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6865 - loss: 1.0206 - val_accuracy: 0.2021 - val_loss: 4.3553
# Epoch 225/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6525 - loss: 1.1225 - val_accuracy: 0.2161 - val_loss: 4.4302
# Epoch 226/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6770 - loss: 1.0362 - val_accuracy: 0.2041 - val_loss: 4.2426
# Epoch 227/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6752 - loss: 1.0645 - val_accuracy: 0.1988 - val_loss: 4.5151
# Epoch 228/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6641 - loss: 1.0621 - val_accuracy: 0.2108 - val_loss: 4.3721
# Epoch 229/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6817 - loss: 1.0268 - val_accuracy: 0.2081 - val_loss: 4.3702
# Epoch 230/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6794 - loss: 1.0273 - val_accuracy: 0.1988 - val_loss: 4.4585
# Epoch 231/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6654 - loss: 1.0493 - val_accuracy: 0.2101 - val_loss: 4.4839
# Epoch 232/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6717 - loss: 1.0284 - val_accuracy: 0.1948 - val_loss: 4.4153
# Epoch 233/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6860 - loss: 1.0082 - val_accuracy: 0.1981 - val_loss: 4.4258
# Epoch 234/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6645 - loss: 1.0572 - val_accuracy: 0.2028 - val_loss: 4.5176
# Epoch 235/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6625 - loss: 1.0478 - val_accuracy: 0.2135 - val_loss: 4.4824
# Epoch 236/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6833 - loss: 0.9785 - val_accuracy: 0.2008 - val_loss: 4.5342
# Epoch 237/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6717 - loss: 1.0285 - val_accuracy: 0.2075 - val_loss: 4.3803
# Epoch 238/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6874 - loss: 0.9985 - val_accuracy: 0.1948 - val_loss: 4.6182
# Epoch 239/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6889 - loss: 1.0070 - val_accuracy: 0.2021 - val_loss: 4.5356
# Epoch 240/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6887 - loss: 0.9944 - val_accuracy: 0.2161 - val_loss: 4.2810
# Epoch 241/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6984 - loss: 0.9567 - val_accuracy: 0.2115 - val_loss: 4.3552
# Epoch 242/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6985 - loss: 0.9779 - val_accuracy: 0.2055 - val_loss: 4.4737
# Epoch 243/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6904 - loss: 0.9968 - val_accuracy: 0.2021 - val_loss: 4.7036
# Epoch 244/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7104 - loss: 0.9144 - val_accuracy: 0.1988 - val_loss: 4.5468
# Epoch 245/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6963 - loss: 0.9855 - val_accuracy: 0.2088 - val_loss: 4.4509
# Epoch 246/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6709 - loss: 1.0311 - val_accuracy: 0.2035 - val_loss: 4.5252
# Epoch 247/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6822 - loss: 1.0099 - val_accuracy: 0.2121 - val_loss: 4.5637
# Epoch 248/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7221 - loss: 0.9065 - val_accuracy: 0.2088 - val_loss: 4.4347
# Epoch 249/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7016 - loss: 0.9354 - val_accuracy: 0.1988 - val_loss: 4.4957
# Epoch 250/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7047 - loss: 0.9522 - val_accuracy: 0.2155 - val_loss: 4.4321
# Epoch 251/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7061 - loss: 0.9090 - val_accuracy: 0.2128 - val_loss: 4.7294
# Epoch 252/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7020 - loss: 0.9356 - val_accuracy: 0.2161 - val_loss: 4.4295
# Epoch 253/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7104 - loss: 0.9126 - val_accuracy: 0.2028 - val_loss: 4.5049
# Epoch 254/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7072 - loss: 0.9102 - val_accuracy: 0.2155 - val_loss: 4.5354
# Epoch 255/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7234 - loss: 0.8911 - val_accuracy: 0.2035 - val_loss: 4.5697
# Epoch 256/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7185 - loss: 0.9000 - val_accuracy: 0.2108 - val_loss: 4.5381
# Epoch 257/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7122 - loss: 0.9005 - val_accuracy: 0.2115 - val_loss: 4.4640
# Epoch 258/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7345 - loss: 0.8611 - val_accuracy: 0.2095 - val_loss: 4.5787
# Epoch 259/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7245 - loss: 0.8811 - val_accuracy: 0.1988 - val_loss: 4.6552
# Epoch 260/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7245 - loss: 0.8671 - val_accuracy: 0.2055 - val_loss: 4.5562
# Epoch 261/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7177 - loss: 0.8901 - val_accuracy: 0.2215 - val_loss: 4.4786
# Epoch 262/1000
# ...
# Epoch 900/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9341 - loss: 0.2129 - val_accuracy: 0.2382 - val_loss: 6.7025
# Epoch 901/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9380 - loss: 0.1831 - val_accuracy: 0.2375 - val_loss: 6.8461
# Epoch 902/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9273 - loss: 0.2194 - val_accuracy: 0.2342 - val_loss: 7.1812
# Epoch 903/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9388 - loss: 0.1898 - val_accuracy: 0.2495 - val_loss: 6.8490
# Epoch 904/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9314 - loss: 0.2113 - val_accuracy: 0.2435 - val_loss: 6.6819
# Epoch 905/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9340 - loss: 0.2140 - val_accuracy: 0.2308 - val_loss: 6.5287
# Epoch 906/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9273 - loss: 0.2223 - val_accuracy: 0.2408 - val_loss: 6.4287
# Epoch 907/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9352 - loss: 0.1884 - val_accuracy: 0.2402 - val_loss: 7.0548
# Epoch 908/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9263 - loss: 0.2302 - val_accuracy: 0.2455 - val_loss: 6.7339
# Epoch 909/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9316 - loss: 0.2110 - val_accuracy: 0.2208 - val_loss: 6.8742
# Epoch 910/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9346 - loss: 0.2087 - val_accuracy: 0.2448 - val_loss: 6.5767
# Epoch 911/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9234 - loss: 0.2157 - val_accuracy: 0.2335 - val_loss: 6.9368
# Epoch 912/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9244 - loss: 0.2417 - val_accuracy: 0.2455 - val_loss: 6.8446
# Epoch 913/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9289 - loss: 0.2117 - val_accuracy: 0.2408 - val_loss: 6.8576
# Epoch 914/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9285 - loss: 0.2239 - val_accuracy: 0.2355 - val_loss: 6.6527
# Epoch 915/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9324 - loss: 0.2024 - val_accuracy: 0.2362 - val_loss: 6.8169
# Epoch 916/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9324 - loss: 0.2030 - val_accuracy: 0.2322 - val_loss: 6.3731
# Epoch 917/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9264 - loss: 0.2197 - val_accuracy: 0.2315 - val_loss: 6.9334
# Epoch 918/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9322 - loss: 0.2211 - val_accuracy: 0.2322 - val_loss: 6.6837
# Epoch 919/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9343 - loss: 0.1929 - val_accuracy: 0.2448 - val_loss: 6.9610
# Epoch 920/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9247 - loss: 0.2422 - val_accuracy: 0.2442 - val_loss: 6.8821
# Epoch 921/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9229 - loss: 0.2235 - val_accuracy: 0.2275 - val_loss: 6.5916
# Epoch 922/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9286 - loss: 0.2122 - val_accuracy: 0.2362 - val_loss: 6.5671
# Epoch 923/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9221 - loss: 0.2452 - val_accuracy: 0.2588 - val_loss: 6.3166
# Epoch 924/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9209 - loss: 0.2434 - val_accuracy: 0.2388 - val_loss: 6.4483
# Epoch 925/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9286 - loss: 0.2119 - val_accuracy: 0.2208 - val_loss: 6.8208
# Epoch 926/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9334 - loss: 0.2238 - val_accuracy: 0.2155 - val_loss: 6.9670
# Epoch 927/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9315 - loss: 0.2149 - val_accuracy: 0.2355 - val_loss: 6.7629
# Epoch 928/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9238 - loss: 0.2399 - val_accuracy: 0.2502 - val_loss: 6.7146
# Epoch 929/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9328 - loss: 0.2106 - val_accuracy: 0.2375 - val_loss: 6.6032
# Epoch 930/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9304 - loss: 0.1927 - val_accuracy: 0.2355 - val_loss: 6.8117
# Epoch 931/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9263 - loss: 0.2418 - val_accuracy: 0.2482 - val_loss: 6.5866
# Epoch 932/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9331 - loss: 0.2284 - val_accuracy: 0.2282 - val_loss: 6.9069
# Epoch 933/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9382 - loss: 0.1930 - val_accuracy: 0.2241 - val_loss: 7.0148
# Epoch 934/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9337 - loss: 0.2195 - val_accuracy: 0.2255 - val_loss: 7.3591
# Epoch 935/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9211 - loss: 0.2331 - val_accuracy: 0.2442 - val_loss: 7.0502
# Epoch 936/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9381 - loss: 0.1997 - val_accuracy: 0.2395 - val_loss: 7.0328
# Epoch 937/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9240 - loss: 0.2361 - val_accuracy: 0.2435 - val_loss: 6.9171
# Epoch 938/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9345 - loss: 0.2086 - val_accuracy: 0.2215 - val_loss: 7.0806
# Epoch 939/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9291 - loss: 0.2119 - val_accuracy: 0.2248 - val_loss: 7.3439
# Epoch 940/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9169 - loss: 0.2336 - val_accuracy: 0.2528 - val_loss: 6.4881
# Epoch 941/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9234 - loss: 0.2514 - val_accuracy: 0.2395 - val_loss: 7.0011
# Epoch 942/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9307 - loss: 0.2175 - val_accuracy: 0.2402 - val_loss: 6.4187
# Epoch 943/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9334 - loss: 0.2132 - val_accuracy: 0.2602 - val_loss: 6.7887
# Epoch 944/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9261 - loss: 0.2347 - val_accuracy: 0.2422 - val_loss: 6.7403
# Epoch 945/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9354 - loss: 0.2020 - val_accuracy: 0.2575 - val_loss: 6.9078
# Epoch 946/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9371 - loss: 0.1850 - val_accuracy: 0.2422 - val_loss: 6.8950
# Epoch 947/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9236 - loss: 0.2422 - val_accuracy: 0.2495 - val_loss: 6.9561
# Epoch 948/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9304 - loss: 0.2127 - val_accuracy: 0.2548 - val_loss: 6.8064
# Epoch 949/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9361 - loss: 0.1982 - val_accuracy: 0.2528 - val_loss: 6.7882
# Epoch 950/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9364 - loss: 0.1944 - val_accuracy: 0.2528 - val_loss: 6.5100
# Epoch 951/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9251 - loss: 0.2238 - val_accuracy: 0.2395 - val_loss: 6.6655
# Epoch 952/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9387 - loss: 0.1998 - val_accuracy: 0.2255 - val_loss: 7.0082
# Epoch 953/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9359 - loss: 0.1986 - val_accuracy: 0.2275 - val_loss: 6.8848
# Epoch 954/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9329 - loss: 0.2190 - val_accuracy: 0.2448 - val_loss: 6.9572
# Epoch 955/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9340 - loss: 0.2182 - val_accuracy: 0.2335 - val_loss: 6.6171
# Epoch 956/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9300 - loss: 0.2239 - val_accuracy: 0.2335 - val_loss: 6.7807
# Epoch 957/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9345 - loss: 0.2143 - val_accuracy: 0.2428 - val_loss: 6.7815
# Epoch 958/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9305 - loss: 0.2176 - val_accuracy: 0.2322 - val_loss: 6.7073
# Epoch 959/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9229 - loss: 0.2405 - val_accuracy: 0.2282 - val_loss: 7.0932
# Epoch 960/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9307 - loss: 0.2134 - val_accuracy: 0.2342 - val_loss: 7.0016
# Epoch 961/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9413 - loss: 0.1918 - val_accuracy: 0.2388 - val_loss: 7.0246
# Epoch 962/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9428 - loss: 0.1684 - val_accuracy: 0.2382 - val_loss: 6.5867
# Epoch 963/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9229 - loss: 0.2322 - val_accuracy: 0.2295 - val_loss: 6.7466
# Epoch 964/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9386 - loss: 0.1883 - val_accuracy: 0.2282 - val_loss: 6.9549
# Epoch 965/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9241 - loss: 0.2313 - val_accuracy: 0.2448 - val_loss: 6.8082
# Epoch 966/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9371 - loss: 0.1909 - val_accuracy: 0.2382 - val_loss: 7.1126
# Epoch 967/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9393 - loss: 0.1772 - val_accuracy: 0.2388 - val_loss: 6.7723
# Epoch 968/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9299 - loss: 0.2013 - val_accuracy: 0.2128 - val_loss: 6.9504
# Epoch 969/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9301 - loss: 0.1989 - val_accuracy: 0.2282 - val_loss: 6.6057
# Epoch 970/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9328 - loss: 0.2114 - val_accuracy: 0.2455 - val_loss: 6.9905
# Epoch 971/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9236 - loss: 0.2552 - val_accuracy: 0.2375 - val_loss: 7.0934
# Epoch 972/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9305 - loss: 0.2255 - val_accuracy: 0.2288 - val_loss: 6.8016
# Epoch 973/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9382 - loss: 0.2027 - val_accuracy: 0.2422 - val_loss: 6.8803
# Epoch 974/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9427 - loss: 0.1922 - val_accuracy: 0.2382 - val_loss: 6.9109
# Epoch 975/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9447 - loss: 0.2036 - val_accuracy: 0.2241 - val_loss: 7.0479
# Epoch 976/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9302 - loss: 0.2197 - val_accuracy: 0.2382 - val_loss: 7.1975
# Epoch 977/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9414 - loss: 0.1763 - val_accuracy: 0.2302 - val_loss: 6.9574
# Epoch 978/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9404 - loss: 0.2080 - val_accuracy: 0.2422 - val_loss: 6.6441
# Epoch 979/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9336 - loss: 0.1998 - val_accuracy: 0.2422 - val_loss: 6.7289
# Epoch 980/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9461 - loss: 0.1661 - val_accuracy: 0.2448 - val_loss: 7.2041
# Epoch 981/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9259 - loss: 0.2329 - val_accuracy: 0.2488 - val_loss: 6.8377
# Epoch 982/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9330 - loss: 0.1980 - val_accuracy: 0.2395 - val_loss: 6.7779
# Epoch 983/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9359 - loss: 0.1868 - val_accuracy: 0.2388 - val_loss: 6.8434
# Epoch 984/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9395 - loss: 0.1833 - val_accuracy: 0.2435 - val_loss: 6.7970
# Epoch 985/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9210 - loss: 0.2623 - val_accuracy: 0.2388 - val_loss: 6.3163
# Epoch 986/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9379 - loss: 0.1938 - val_accuracy: 0.2362 - val_loss: 6.9936
# Epoch 987/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9361 - loss: 0.2132 - val_accuracy: 0.2415 - val_loss: 6.8269
# Epoch 988/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9266 - loss: 0.2055 - val_accuracy: 0.2348 - val_loss: 6.7058
# Epoch 989/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9385 - loss: 0.1775 - val_accuracy: 0.2362 - val_loss: 6.8595
# Epoch 990/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9353 - loss: 0.1857 - val_accuracy: 0.2495 - val_loss: 6.5546
# Epoch 991/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9267 - loss: 0.2056 - val_accuracy: 0.2282 - val_loss: 6.7628
# Epoch 992/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9452 - loss: 0.2009 - val_accuracy: 0.2328 - val_loss: 7.0529
# Epoch 993/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9420 - loss: 0.1806 - val_accuracy: 0.2335 - val_loss: 7.1567
# Epoch 994/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9290 - loss: 0.2184 - val_accuracy: 0.2328 - val_loss: 7.0005
# Epoch 995/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9224 - loss: 0.2459 - val_accuracy: 0.2241 - val_loss: 7.1370
# Epoch 996/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9348 - loss: 0.2011 - val_accuracy: 0.2295 - val_loss: 7.1381
# Epoch 997/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9334 - loss: 0.2106 - val_accuracy: 0.2348 - val_loss: 7.1674
# Epoch 998/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9339 - loss: 0.1972 - val_accuracy: 0.2348 - val_loss: 7.1051
# Epoch 999/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9381 - loss: 0.1923 - val_accuracy: 0.2435 - val_loss: 7.0903
# Epoch 1000/1000
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9263 - loss: 0.2430 - val_accuracy: 0.2475 - val_loss: 6.8802
#
# Training Time: 1460.7129 seconds [24.35 minutes]
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.2476 - loss: 6.6778
# Test loss: 6.786847114562988
# Test accuracy: 0.2446666657924652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step
# Confusion matrix saved as 'confusion_matrix.png'
# Macro Avg - Precision: 0.278, Recall: 0.245, F1-Score: 0.249
#
# Top 5 Best Performing Breeds (by F1-Score):
#                             f1-score
# n02085936-Maltese_dog       0.539683
# n02095889-Sealyham_terrier  0.520000
# n02106550-Rottweiler        0.509091
# n02085782-Japanese_spaniel  0.490566
# n02086910-papillon          0.425532
#
# Top 5 Worst Performing Breeds (by F1-Score):
#                               f1-score
# n02113799-standard_poodle     0.030769
# n02088364-beagle              0.065574
# n02091032-Italian_greyhound   0.071429
# n02099712-Labrador_retriever  0.095238
# n02113624-toy_poodle          0.101695
